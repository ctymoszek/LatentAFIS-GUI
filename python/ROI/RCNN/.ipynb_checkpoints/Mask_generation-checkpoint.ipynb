# %% [markdown]
# ## Generate Finger mask

# %%
import os
os.environ["KERAS_BACKEND"]= 'tensorflow'
os.environ["CUDA_VISIBLE_DEVICES"] = '1'

# %%
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import utils
import visualize
from visualize import display_images
import model as modellib
from model import log
import scipy.misc
import skimage.io as io
import skimage.io

sys.path.append("./TensorVision")

import tensorvision.utils as tv_utils


from hist_util import histeq

# %matplotlib inline 

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")


from config import Config
class ShapesConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # background + 1 finger class

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 128
    #For NISTSD27: 800, WVU: 1024 
    #IMAGE_MAX_DIM = 1024
    IMAGE_MAX_DIM = 800

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 500

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 15
    
    DETECTION_MIN_CONFIDENCE = 0
    
config = ShapesConfig()
#config.display()

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"

def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax


class ShapesDataset(utils.Dataset):

    def load_shapes(self, DATA_DIR, height, width):
        """Create queue to load images into queue
        height, width: the size of the images.
        """
        # Add classes: prepare for general
        self.add_class("shapes", 1, "fingerprint")
        
        # Pair: (Image, Mask)
        # You can read all images from the path
        
        # Read Image from path
        name_images = []
        for root, subdirs, files in os.walk(DATA_DIR + '/Image/'):
            for file in files:
                if os.path.splitext(file)[1].lower() in ('.bmp', '.jpg', '.jpeg'):
                    name_images.append(os.path.join(root, file))
        # Read Mask from path
        name_masks = []
        for root, subdirs, files in os.walk(DATA_DIR + '/Mask/'):
            for file in files:
                if os.path.splitext(file)[1].lower() in ('.bmp', '.jpg', '.jpeg'):
                    name_masks.append(os.path.join(root, file))
                    
        print "Total %d raw images" %len(name_images)
        print "Total %d raw masks" %len(name_masks)
        name_images = sorted(name_images)
        name_masks = sorted(name_masks)
        
        for i in range(0, len(name_images)):
            self.add_image("shapes", image_id=i, path=name_images[i],
                       width=width, height=height)
            self.add_mask("shapes", image_id=i, path=name_masks[i],
                       width=width, height=height)
        

    def load_image(self, image_id):
        """Load the specified image and return a [H,W,3] Numpy array.
        """
        
        # Load image
        image = skimage.io.imread(self.image_info[image_id]['path'])

        # If grayscale. Convert to RGB for consistency.
        if image.ndim != 3:
            image = skimage.color.gray2rgb(image)
        return image

    def load_mask_image(self, mask_id):
        """Load the specified original mask image
        """
        
        # Load image
        image = skimage.io.imread(self.mask_info[mask_id]['path'])

        return image
    
    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)

            
    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        
        # Hardcoding -> TODO: need to change
        shapes = ['fingerprint']
        count = len(shapes)
        
        mask_o = skimage.io.imread(self.mask_info[image_id]['path'])/255

        mask = np.zeros([mask_o.shape[0], mask_o.shape[1], count], dtype=np.uint8)
        for i in range(0, count):
            mask[:, :, i] = mask_o        
        
        # Map class names to class IDs.
        class_ids = np.array([1])
        return mask, class_ids.astype(np.int32)


def imhist(im):
  # calculates normalized histogram of an image
	m, n = im.shape
	h = [0.0] * 256
	for i in range(m):
		for j in range(n):
			h[im[i, j]]+=1
	return np.array(h)/(m*n)

def cumsum(h):
	# finds cumulative sum of a numpy array, list
	return [sum(h[:i+1]) for i in range(len(h))]

def histeq(im):
	#calculate Histogram
	h = imhist(im)
	cdf = np.array(cumsum(h)) #cumulative distribution function
	sk = np.uint8(255 * cdf) #finding transfer function values
	s1, s2 = im.shape
	Y = np.zeros_like(im)
	# applying transfered values for each pixels
	for i in range(0, s1):
		for j in range(0, s2):
			Y[i, j] = sk[im[i, j]]
	H = imhist(Y)
	#return transformed image, original and new istogram, 
	# and transform function
	return Y , h, H, sk


class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    RPN_NMS_THRESHOLD = 0.7  # This is important because of threshold:
    DETECTION_MIN_CONFIDENCE = 0.3 # 0.5 is best Seems a little
    DETECTION_NMS_THRESHOLD = 0 # Seems nothing
    RPN_ANCHOR_STRIDE = 1
    RPN_ANCHOR_RATIOS = [0.25, 0.5, 0.75]
    #MEAN_PIXEL = [128, 128, 128]
    #ROI_POSITIVE_RATIO = 0.5 # seems nothing
    #RPN_ANCHOR_RATIOS = [0.5, 1, 2]
    
    #RPN_ANCHOR_SCALES = (4, 8, 16, 32, 64)
    #ROI_POSITIVE_RATIO = 0.1
    #IMAGE_MAX_DIM = 800
    #IMAGE_MIN_DIM = 128

inference_config = InferenceConfig()
#inference_config.display()


def IoU(predict, groundtruth):
    intersection = predict & groundtruth
    union = predict | groundtruth
    iou1 = sum(sum(1.0*intersection))/sum(sum(1.0*union))

    predict = 1 - predict
    groundtruth = 1 - groundtruth
    
    intersection = predict & groundtruth
    union = predict | groundtruth
    iou2 = sum(sum(1.0*intersection))/sum(sum(1.0*union))
    return (iou1+iou2)/2

def to_rgb(im):
    # I think this will be slow
    w, h = im.shape
    ret = np.empty((w, h, 3), dtype=np.uint8)
    ret[:, :, 0] = im
    ret[:, :, 1] = im
    ret[:, :, 2] = im
    return ret

def revert(image):
    image[:,:,0] = 255-image[:,:,0]
    image[:,:,1] = 255-image[:,:,1]
    image[:,:,2] = 255-image[:,:,2]  
    return image

def to_one_depth(im):
    # I think this will be slow
    w, h = im.shape
    ret = np.empty((w, h, 1), dtype=np.uint8)
    ret[:, :, 0] = im
    return ret

def calculate_cumulative_mask(model, base_image, begin_thres = -10, end_thres = 10, step = 10):
    # base_image has shape (w, h, 3)
    cumulative_mask = base_image[:,:,0]*0
    
    for thres in range(begin_thres, end_thres+1, step): # -10, 0, 10 is best for after hist equal
        image = base_image + thres
    
        # Run object detection
        results = model.detect([image], verbose=0, threshold_mask = 0.7)
        r = results[0]
        
        if r['masks'].shape[0] > 0:
            cumulative_mask += r['masks'][:,:,0]
        
    return cumulative_mask



#print("Images: {}\nClasses: {}".format(len(dataset_val.image_ids), dataset_val.class_names))

#MODEL_DIR =  "/research/prip-nguye590/Segmentation/Mask_RCNN/logs/shapes20171215T0924/mask_rcnn_shapes_0305.h5"
#MODEL_DIR =  "/research/prip-nguye590/Segmentation/Mask_RCNN/logs/shapes20171224T1316/mask_rcnn_shapes_0450.h5"
#MODEL_DIR =  "/research/prip-nguye590/Segmentation/Mask_RCNN/logs/shapes20171228T1329/mask_rcnn_shapes_0033.h5"
#MODEL_DIR =  "/research/prip-nguye590/Segmentation/Mask_RCNN/logs/shapes20171228T1329/mask_rcnn_shapes_0140.h5"


CHANGE_PATH = '/research/prip-nguye590/Segmentation/Mask_RCNN/Masked_image/send_Kai_v2'

def load_model(MODEL_DIR):
    # Create model in inference mode
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                                  config=inference_config)

    weights_path = MODEL_DIR

    # Load weights
    print("Loading weights ", weights_path)
    model.load_weights(weights_path, by_name=True)
    return model
    

def generate_mask(model, CHANGE_PATH, DATA_DIR, gen_type = 'bmp', fuse_thres = 1):    

    # Validation dataset
    dataset_val = ShapesDataset()
    dataset_val.load_shapes(DATA_DIR, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
    dataset_val.prepare()

    # Must call before using the dataset
    dataset_val.prepare()

    dataset = dataset_val

    
    
    for image_id in dataset.image_ids:
    #for image_id in [1, 2]:
        #image_id = 241 173 195 132 219
        original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
            modellib.load_image_gt(dataset_val, config, image_id, use_mini_mask=False)
        
        # Voting scheme: original image and equalized image are feed to give the result with variance of gray scale value is 
        # from -10 to 10. The result is the region that have the 3/6 point value in area.

        # Initialize the cumulative mask as 0
        cumulative_mask = gt_mask[:,:,0]*0
        cumulative_box = gt_mask[:,:,0]*0

        #"""
        # Normalize mean to 128:
        normal_image = np.uint8(original_image + 128 - np.mean(original_image))
        #original_image = normal_image

        # original_image has 3 channels as the same
        equalized_img_gray, _, _, _ = histeq(original_image[:,:,0])    
        # Processing Histogram equalized image
        equalized_img_rgb = to_rgb(equalized_img_gray)

        # Revert original_image
        #original_image = revert(original_image)

        cumulative_mask += calculate_cumulative_mask(model, normal_image, -50, 51)
        cumulative_mask += calculate_cumulative_mask(model, equalized_img_rgb, -50, 51)
        cumulative_mask += calculate_cumulative_mask(model, original_image, -50, 51)    

        THRESHOLD_CUMULATIVE_MASK = fuse_thres

        thres_compare = min(THRESHOLD_CUMULATIVE_MASK,np.max(np.max(cumulative_mask)))

        # Bitwise compare to get the mask that each pixel has value of THRESHOLD_CUMULATIVE_MASK
        cumulative_mask = (cumulative_mask >= thres_compare)*1

        # Bounding box wrap the mask
        pad = 0
        # Check if having mask return; if no mask, then box is the full image
        if np.sum(np.sum(cumulative_mask))>0:
            bbox = utils.extract_bboxes(to_one_depth(cumulative_mask))
            cumulative_box[max(0,bbox[0,0]-pad):min(config.IMAGE_MAX_DIM-1,bbox[0,2]+pad), max(0,bbox[0,1]-pad):min(config.IMAGE_MAX_DIM-1,bbox[0,3]+pad)] = 1
        else:
            cumulative_box[:,:] = 1

        # Visualization
        #output = tv_utils.fast_overlay(original_image, gt_mask, [1, 255, 0, 127])
        #output = tv_utils.fast_overlay(output, cumulative_mask, [1, 0, 255, 127])
        #plt.show()
        #io.imshow(output)
        #"""
        # Filter Image after Mask
        #image_after_mask = original_image[:,:,0]*cumulative_mask
        #image_after_box = original_image[:,:,0]*cumulative_box

        image_after_mask = equalized_img_rgb[:,:,0]*cumulative_mask
        image_after_box = equalized_img_rgb[:,:,0]*cumulative_box

        #Check the case it is all black
        if np.sum(np.sum(image_after_mask))==0:
            image_after_mask = original_image[:,:,0]
        if np.sum(np.sum(image_after_box))==0:
            image_after_box = original_image[:,:,0]

        #plt.set_cmap('gray')
        #plt.show()
        #plt.imshow(image_after_mask)
        #plt.show()
        #plt.imshow(image_after_box)
        # Resize image into specific size
        #image_after_mask = scipy.misc.imresize(image_after_mask, (800, 800))
        
        pad_width = (config.IMAGE_MAX_DIM - image_meta[1])/2
        pad_height = (config.IMAGE_MAX_DIM - image_meta[2])/2
        # Chua xu li truong hop resize from small size to ori
        if pad_width > 0 && pad_height > 0:
            if gen_type == 'box':
                SAVE_MASKED_IMG_DIR_BOX = CHANGE_PATH + '_box/'
                if not os.path.exists(SAVE_MASKED_IMG_DIR_BOX):
                    os.makedirs(SAVE_MASKED_IMG_DIR_BOX)
                io.imsave(SAVE_MASKED_IMG_DIR_BOX + '%d_masked.bmp'%(image_id+1), cumulative_box[pad_width:config.IMAGE_MAX_DIM - pad_width, pad_height:config.IMAGE_MAX_DIM - pad_height]*255)
            if gen_type == 'bmp':
                SAVE_MASKED_IMG_DIR_BMP = CHANGE_PATH + '_bmp/'
                if not os.path.exists(SAVE_MASKED_IMG_DIR_BMP):
                    os.makedirs(SAVE_MASKED_IMG_DIR_BMP)
                io.imsave(SAVE_MASKED_IMG_DIR_BMP + '%d_masked.bmp'%(image_id+1), cumulative_mask[pad_width:config.IMAGE_MAX_DIM - pad_width, pad_height:config.IMAGE_MAX_DIM - pad_height]*255)

        # Save image
        #io.imsave(SAVE_MASKED_IMG_DIR_BMP + '%d_masked.bmp'%(image_id+1), image_after_mask)
        #io.imsave(SAVE_MASKED_IMG_DIR_BOX + '%d_masked.bmp'%(image_id+1), image_after_box)

        
        
        #"""
# Out:
# Using TensorFlow backend.

# %%
mymodel = load_model('/home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/model_1_0140.h5')
# Out:
# ('Loading weights ', '/home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/model_1_0140.h5')

# %%
generate_mask(mymodel, '/home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test',
              '/home/nguye590/Research/prip-nguye590/Datasets/NIST27',
              gen_type = 'bmp', fuse_thres = 3)
# Out:
# Total 258 raw images
# Total 258 raw masks
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/1_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/util/dtype.py:118: UserWarning: Possible sign loss when converting negative image of type int64 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 255 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/2_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/3_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/4_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/5_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/6_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/7_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/8_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/9_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/10_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/11_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/12_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/13_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/14_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/15_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/16_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/17_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/18_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/19_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/20_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/21_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/22_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/23_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/24_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/25_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/26_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/27_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/28_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/29_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/30_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/31_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/32_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/33_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/34_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/35_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/36_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/37_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/38_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/39_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/40_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/41_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/42_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/43_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/44_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/45_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/46_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/47_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/48_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/49_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/50_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/51_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/52_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/53_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/54_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/55_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/56_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/57_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/58_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/59_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/60_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/61_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/62_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/63_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/64_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/65_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/66_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/67_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/68_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/69_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/70_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/71_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/72_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/73_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/74_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/75_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/76_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/77_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/78_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/79_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/80_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/81_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/82_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/83_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/84_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/85_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/86_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/87_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/88_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/89_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/90_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/91_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/92_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/93_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/94_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/95_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/96_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/97_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/98_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/99_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/100_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/101_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/102_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/103_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/104_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/105_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/106_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/107_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/108_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/109_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/110_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/111_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/112_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/113_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/114_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/115_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/116_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/117_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/118_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/119_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/120_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/121_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/122_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/123_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/124_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/125_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/126_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/127_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/128_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/129_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/130_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/131_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/132_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/133_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/134_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/135_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/136_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/137_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/138_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/139_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/140_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/141_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/142_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/143_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/144_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/145_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/146_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/147_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/148_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/149_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test_bmp/150_masked.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0aaa1d434a12> in <module>()
#       1 generate_mask(mymodel, '/home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/output_mask/luan_test',
#       2               '/home/nguye590/Research/prip-nguye590/Datasets/NIST27',
# ----> 3               gen_type = 'bmp', fuse_thres = 3)
#
# <ipython-input-2-6d322136e255> in generate_mask(model, CHANGE_PATH, DATA_DIR, gen_type, fuse_thres)
#     345         #original_image = revert(original_image)
#     346
# --> 347         cumulative_mask += calculate_cumulative_mask(model, normal_image, -50, 51)
#     348         cumulative_mask += calculate_cumulative_mask(model, equalized_img_rgb, -50, 51)
#     349         cumulative_mask += calculate_cumulative_mask(model, original_image, -50, 51)
#
# <ipython-input-2-6d322136e255> in calculate_cumulative_mask(model, base_image, begin_thres, end_thres, step)
#     273
#     274         # Run object detection
# --> 275         results = model.detect([image], verbose=0, threshold_mask = 0.7)
#     276         r = results[0]
#     277
#
# /home/nguye590/Research/prip-nguye590/Latent_matching_hub/Segmentation/model.pyc in detect(self, images, verbose, threshold_mask)
#    2338         detections, mrcnn_class, mrcnn_bbox, mrcnn_mask, \
#    2339             rois, rpn_class, rpn_bbox =\
# -> 2340             self.keras_model.predict([molded_images, image_metas], verbose=0)
#    2341         # Process detections
#    2342         results = []
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1746         f = self.predict_function
#    1747         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1748                                   verbose=verbose, steps=steps)
#    1749
#    1750     def train_on_batch(self, x, y,
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1297                 else:
#    1298                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1299                 batch_outs = f(ins_batch)
#    1300                 if not isinstance(batch_outs, list):
#    1301                     batch_outs = [batch_outs]
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/nguye590/anaconda2/envs/tensorflow-research/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
